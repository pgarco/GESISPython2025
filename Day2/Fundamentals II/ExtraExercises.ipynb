# %% [markdown]
# ## Exercise 1: Dictionaries, Loops and Conditionals
#
# ### **Make a Rock-Paper-Scissors game.**
#    - Ask for player play (using input)
#    - randomise the computer's pick
#    - print out a message to the player telling them the computer's pick and if they lost/won
#    - ask if the player wants to start a new game
#
# Remember the rules:
# - Rock beats scissors
# - Scissors beats paper
# - Paper beats rock
#
# Extra considerations
#     - If the player enters an invalid option, tell them to pick again until they have picked a valid one
#
# RPS [Solution](https://colab.research.google.com/drive/1usGqtJBKsiJz6UlHEnQGjswZgnEcm_wG)

# %% [markdown]
# ## Exercise 2: Functions
#
# ###Write a function that converts a number to Roman Numerals
#
#
# **Hints**
#
# - I = 1, V = 5, X = 10, L = 50, C = 100, D = 500, M = 1000
# - Zero is not represented
# - Hint: You may be tempted to nest a million ifs. In fact this code can be written entirely without ifs.
#
# Roman Numerals [Solution](https://colab.research.google.com/drive/1plYu5fuioLSmcY0hBqtcHBVvg_FE4BYG#scrollTo=vMq_rQ8b-C_C)

# %% [markdown]
# ## Exercise 3: A Game of Nim
#
# The game Nim starts out with 12 sticks on the table.
# Each player takes turns picking up 1, 2 or 3 sticks and cannot pass.
# Whoever picks up the last stick wins.
#
# Hint: The computer should pick sticks at random. Take a look at the random module (import random)
#
# Input:
# * The number of sticks the player is picking up
#
# Output:
# * The number of sticks on the table
# * Who won (the player or the computer)
# * Other relevant info?
#
# **Extra Credit:**
# Let's make the computer smarter. Can you make it so the computer always wins?
#
#
# Hints:
# * Break down the problem into smaller problems.
# * Think of your problem's flow before you start writing the code.
# * If you need to visualise it, map out a flow-chart.
#
# A game of Nim [Solution](https://colab.research.google.com/drive/1ogmqNfw6pfCS1HdxqO8ZAiVt_y34pl3y)

# %% [markdown]
# ## Exercise 4: Functions
#
# The Fibonnaci seqence is a sequence of numbers where the next number in the sequence is the sum of the previous two numbers in the sequence. The sequence looks like this: 1, 1, 2, 3, 5, 8, 13, …
#
# The 7th Fibonacci number is 13. What is the Fibonacci(8)?
#
# Let's write a program that calculates the nth number in the Fibonacci sequence.
#
# Hint: You can use recursion or not. Your choice, but which do you think is more efficient?
#
# Fibonacci [solution](https://colab.research.google.com/drive/1Cs7acG3Znn-AWniV_EmfPd4B9XfXxPTB?usp=sharing)
